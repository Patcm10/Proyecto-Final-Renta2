# %%
import pandas as pd
import googlemaps

# %%
lista_depa_numeros = pd.read_csv('Web-Scrapping-Proyecto Final.csv', sep="|")
lista_depa_numeros.head()
# Out:
#                                              Address  Price(MX$)  Bedrooms  \
# 0    Tokio 65, A1, Juárez, Cuauhtémoc, Distrito F...       30000         2
# 1    Azalea 152, Lomas Quebradas, La Magdalena Co...       13500         2
# 2    Lago Iseo 532, Be Grand Alto Polanc, Colonia...       35000         2
# 3    Congreso 113, La Joya, Tlalpan, Distrito Fed...       11350         2
# 4    Rómulo O'farril 520, Colonia Olivar De Los P...       14500         2
#
#   Bathrooms Size(m2)
# 0       2.0      107
# 1       2.0      140
# 2       2.0      109
# 3       1.0      102
# 4       2.0       76

# %%
null_cols = lista_depa_numeros.isnull().sum()
null_cols[null_cols > 0]
# Out:
# Series([], dtype: int64)

# %%
lista_depa_numeros['Bathrooms'].fillna('-', inplace=True)

# %%
lista_depa_numeros.head()
# Out:
#                                              Address  Price(MX$)  Bedrooms  \
# 0    Tokio 65, A1, Juárez, Cuauhtémoc, Distrito F...       30000         2
# 1    Azalea 152, Lomas Quebradas, La Magdalena Co...       13500         2
# 2    Lago Iseo 532, Be Grand Alto Polanc, Colonia...       35000         2
# 3    Congreso 113, La Joya, Tlalpan, Distrito Fed...       11350         2
# 4    Rómulo O'farril 520, Colonia Olivar De Los P...       14500         2
#
#   Bathrooms Size(m2)
# 0       2.0      107
# 1       2.0      140
# 2       2.0      109
# 3       1.0      102
# 4       2.0       76

# %%
lista_depa_numeros.to_csv('Web-Scrapping-Proyecto Final.csv', sep="|", index=False)

# %%
add = lista_depa_numeros.Address

# %%
adf = pd.DataFrame(add)

# %%
adf.head()
# Out:
#                                              Address
# 0    Tokio 65, A1, Juárez, Cuauhtémoc, Distrito F...
# 1    Azalea 152, Lomas Quebradas, La Magdalena Co...
# 2    Lago Iseo 532, Be Grand Alto Polanc, Colonia...
# 3    Congreso 113, La Joya, Tlalpan, Distrito Fed...
# 4    Rómulo O'farril 520, Colonia Olivar De Los P...

# %%
gmaps_key = googlemaps.Client(key='AIzaSyDorBIc0q9eHffluSdgaR2th-0-SB7obgg')

# %%
adf['Latitud'] = None
adf['Longitud'] = None

for i in range(0,len(adf),1):
    geocode_result = gmaps_key.geocode(adf.iat[i,0])
    try:
        lat = geocode_result[0]['geometry']['location']['lat']
        lon = geocode_result[0]['geometry']['location']['lng']
        adf.iat[i,adf.columns.get_loc('Latitud')]= lat
        adf.iat[i,adf.columns.get_loc('Longitud')]= lon
    except:
        lat = None
        lon = None

# %%
adf
# Out:
#                                                Address  Latitud Longitud
# 0      Tokio 65, A1, Juárez, Cuauhtémoc, Distrito F...  19.4237 -99.1722
# 1      Azalea 152, Lomas Quebradas, La Magdalena Co...  19.3142 -99.2461
# 2      Lago Iseo 532, Be Grand Alto Polanc, Colonia...   19.441 -99.1819
# 3      Congreso 113, La Joya, Tlalpan, Distrito Fed...  19.2803 -99.1682
# 4      Rómulo O'farril 520, Colonia Olivar De Los P...  19.3378 -99.2146
# 5      Av. Emiliano Zapata 409, Santa Cruz Atoyac, ...   19.369 -99.1611
# 6      1a Privada De La 5 Cerrada De Av Mexico 5, C...  19.3645 -99.2999
# 7      Jorge Bernard Shaw 10 10, 202, Polanco, Migu...  19.4319 -99.2044
# 8      Jorge Bernard Shaw 10 10, 602, Polanco, Migu...  19.4319 -99.2044
# 9      Hegel 210, Polanco, Miguel Hidalgo, Distrito...  19.4351 -99.1879
# 10     Amplísimo, Mide 460m² En Lomas De Chapultepe...  19.4249 -99.2134
# 11     Avenida Santa Fe 482, Cuajimalpa De Morelos,...  19.3595 -99.2699
# ...

# %%
adf.to_csv('Address.csv', sep="|", index=False)
