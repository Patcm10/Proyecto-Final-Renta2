# %%
import re 
from bs4 import BeautifulSoup
import pandas as pd
import requests

# %%
url = 'https://www.inmuebles24.com'
html = requests.get(url).content
html
# Out:
# b'\n\n<!DOCTYPE html>\n<html lang="es">\n\n<head>\n\t<meta charset="UTF-8">\n\t<meta name="viewport" content="width=device-width, initial-scale=1, shrink-to-fit=no, user-scalable=no">\n\t<meta name="format-detection" content="telephone=no">\n\t<meta name="apple-mobile-web-app-capable" content="yes">\n\t<meta http-equiv="X-UA-Compatible" content="ie=edge">\n\t\n<title>Inmuebles en M\xc3\xa9xico: venta y renta de departamentos, casas y otras propiedades - Inmuebles24</title>\n<meta name="keywords" content="" />\n<meta name="description" content="Renta, compra y venta de inmuebles en M\xc3\xa9xico: casas, departamentos, terrenos y otras propiedades. \xc2\xa1El inmueble de tus sue\xc3\xb1os est\xc3\xa1 en Inmuebles24!" />\n<link rel="canonical" href="https://www.inmuebles24.com/">\n<link rel="alternate" media="only screen and (max-width: 640px)" href="https://m.inmuebles24.com/">\n\n\t<link rel="shortcut icon" href="https://img10.naventcdn.com/home/RPHOMv2.4.0-RC8/images/favicon.gif" typ
# ...
